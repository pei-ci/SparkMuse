# %%
"""base_number = 24
peroid_number = 12
note_list = ["C", "C#", "D", "D#", "E", "F", "F#", "G", "G#", "A", "A#", "B"]
def get_note_name(note_number):
    if note_number < 24 or note_number > 127:
        return "C1"
    note_index = (note_number - base_number) % peroid_number
    level = (note_number - base_number) // peroid_number 
    note_name = note_list[note_index]
    note_name = note_name + str(level+1)
    return note_name"""
# Out:
# 'base_number = 24\nperoid_number = 12\nnote_list = ["C", "C#", "D", "D#", "E", "F", "F#", "G", "G#", "A", "A#", "B"]\ndef get_note_name(note_number):\n    if note_number < 24 or note_number > 127:\n        return "C1"\n    note_index = (note_number - base_number) % peroid_number\n    level = (note_number - base_number) // peroid_number \n    note_name = note_list[note_index]\n    note_name = note_name + str(level+1)\n    return note_name'

# %%
def get_note_name(note_number):
    return pretty_midi.note_number_to_name(note_number)

# %%
# 和弦資料
chord_data = {"C": [60, 64, 67], "C/E": [64, 67, 72], "D": [62, 66, 69], "E": [64, 68, 71], "F": [
    65, 69, 72], "G": [67, 71, 74], "G/B": [71, 74, 79], "A": [69, 72, 76], "B": [71, 75, 78],
    "Cm": [60, 63, 67], "Dm": [62, 65, 69], "Em": [64, 67, 71], "Em/G": [67, 71, 76],
    "Fm": [65, 68, 72], "Gm": [67, 72, 76], "Am": [69, 72, 76], "Bm": [71, 74, 78]}
chord_progression_data = {"one": ["C", "G/B", "Am", "Em/G", "F", "C/E", "Dm", "G"],
                          "two": ["C", "Am", "F", "G"], "three": ["F", "G", "Em", "Am", "Dm", "G", "C"],
                          "four": ["Dm", "G", "C", "Am", "Dm", "Em", "F", "G"], "five": ["F", "Em", "Dm", "G", "C"],
                          "six": ["C", "G", "Am", "Em", "F", "C", "F", "G"], "seven": ["Am", "G", "F", "Em", "Dm"],
                          "eight": ["Em", "Am", "F", "G"], "nine": ["C", "Am", "Dm", "G", "C", "Em", "F", "G"]}
melody = {"one": [60, 71, 69, 67, 65, 64, 62, 67], "two": [60, 69, 65, 67], "three": [65, 67, 64, 69, 62, 67, 60],
          "four": [62, 67, 64, 69, 62, 67, 60], "five": [65, 64, 62, 67, 60], "six": [60, 67, 69, 64, 65, 60, 65, 67],
          'seven': [69, 67, 65, 64, 62], 'eight': [64, 69, 65, 67], 'nine': [60, 69, 62, 67, 60, 64, 65, 67]}

# 選擇要使用的和弦進行
chord_progression = "two"


chords = []
for chord in chord_progression_data[chord_progression]:
    chords.append(chord_data[chord])
base_notes = []
for i in range(len(melody[chord_progression])):
    base_notes.append(melody[chord_progression][i]-12)

# %%
import pretty_midi
# Create a PrettyMIDI object
piano_chord = pretty_midi.PrettyMIDI()
# Create an Instrument instance for a cello instrument
piano_program = pretty_midi.instrument_name_to_program('Acoustic Grand Piano')
piano = pretty_midi.Instrument(program=piano_program)

part_number = 1
beat_time=0.5
peroid_time=16
total_time=12
n = (total_time-2*0.5)/(peroid_time*part_number)
print(n)


#type 0 基本和弦進行
whole_note_delta = 2
half_note_delta = whole_note_delta/2
quarter_note_delta = whole_note_delta/4
eighth_note_delta = whole_note_delta/8

time = 0
for i in range(part_number):
    time = (i)*len(base_notes)*whole_note_delta
    for base_note in base_notes:
        note_number = pretty_midi.note_name_to_number(get_note_name(base_note))
        note = pretty_midi.Note(
            velocity=45, pitch=note_number, start=time, end=whole_note_delta)
        piano.notes.append(note)
        time = time + whole_note_delta

    time = (i)*len(base_notes)*whole_note_delta
    for chord in chords:
        for j in range(4):
            for note in chord:
                note_number = pretty_midi.note_name_to_number(get_note_name(note))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=quarter_note_delta)
                piano.notes.append(note)
            time = time + quarter_note_delta
            note_number = pretty_midi.note_name_to_number(get_note_name(21))
            note = pretty_midi.Note(
                velocity=0, pitch=note_number, start=time, end=quarter_note_delta)
            piano.notes.append(note)
    

# Add the cello instrument to the PrettyMIDI object
piano_chord.instruments.append(piano)
# Write out the MIDI data
piano_chord.write('midi_file/base_chord.mid')
# Out:
# libfluidsynth64.dll
# 0.6875

# %%
import pretty_midi
# Create a PrettyMIDI object
piano_chord = pretty_midi.PrettyMIDI()
# Create an Instrument instance for a cello instrument
piano_program = pretty_midi.instrument_name_to_program('Acoustic Grand Piano')
piano = pretty_midi.Instrument(program=piano_program)

part_number = 2
beat_time = 0.5
peroid_time = 16
total_time = 12
n = (total_time-2*0.5)/(peroid_time*part_number)
print(n)

# type 1
whole_note_delta = 2
half_note_delta = whole_note_delta/2
quarter_note_delta = whole_note_delta/4
time = 0
for i in range(part_number):
    time = (i)*len(base_notes)*whole_note_delta*2
    for chord in chords:
        for j in range(2):
            for base_note in chord:
                note_number = pretty_midi.note_name_to_number(get_note_name(base_note-12))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=whole_note_delta)
                piano.notes.append(note)
            time = time + whole_note_delta
            
            note_number = pretty_midi.note_name_to_number(get_note_name(21))
            note = pretty_midi.Note(
                velocity=0, pitch=note_number, start=time, end=whole_note_delta)
            piano.notes.append(note)
            

    time = (i)*len(base_notes)*whole_note_delta*2
    for chord in chords:
        for j in range(4):
            for note in chord:
                note_number = pretty_midi.note_name_to_number(get_note_name(note))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=quarter_note_delta)
                piano.notes.append(note)
            time = time + quarter_note_delta
        for base_note in chord:
            note_number = pretty_midi.note_name_to_number(get_note_name(base_note))
            note = pretty_midi.Note(
                velocity=45, pitch=note_number, start=time, end=whole_note_delta)
            piano.notes.append(note)
        time = time + whole_note_delta
    #time = (i+1-0.5)*len(base_notes_name)*whole_note_delta


# Add the cello instrument to the PrettyMIDI object
piano_chord.instruments.append(piano)
# Write out the MIDI data
piano_chord.write('type1_chord.mid')
# Out:
# 0.34375

# %%
import pretty_midi
# Create a PrettyMIDI object
piano_chord = pretty_midi.PrettyMIDI()
# Create an Instrument instance for a cello instrument
piano_program = pretty_midi.instrument_name_to_program('Acoustic Grand Piano')
piano = pretty_midi.Instrument(program=piano_program)

part_number = 2
beat_time = 0.5
peroid_time = 16
total_time = 12
n = (total_time-2*0.5)/(peroid_time*part_number)
print(n)

# type 2
whole_note_delta = 2
half_note_delta = whole_note_delta/2
quarter_note_delta = whole_note_delta/4
time = 0
for i in range(part_number):
    time = (i)*len(base_notes)*whole_note_delta*2
    for chord in chords:
        for j in range(2):
            for base_note in chord:
                note_number = pretty_midi.note_name_to_number(
                    get_note_name(base_note-12))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=whole_note_delta)
                piano.notes.append(note)
            time = time + whole_note_delta

            note_number = pretty_midi.note_name_to_number(get_note_name(21))
            note = pretty_midi.Note(
                velocity=0, pitch=note_number, start=time, end=whole_note_delta)
            piano.notes.append(note)

    time = (i)*len(base_notes)*whole_note_delta*2
    for chord in chords:
        for j in range(2):
            for note in chord[1:]:
                note_number = pretty_midi.note_name_to_number(
                    get_note_name(note))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=quarter_note_delta)
                piano.notes.append(note)
            time = time + quarter_note_delta
            for note in chord[:1]:
                note_number = pretty_midi.note_name_to_number(
                    get_note_name(note))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=quarter_note_delta)
                piano.notes.append(note)
            time = time + quarter_note_delta
            
        for note in chord[1:]:
            note_number = pretty_midi.note_name_to_number(
                get_note_name(note))
            note = pretty_midi.Note(
                velocity=45, pitch=note_number, start=time, end=quarter_note_delta)
            piano.notes.append(note)
        time = time + quarter_note_delta
        for note in chord[:1]:
            note_number = pretty_midi.note_name_to_number(
                get_note_name(note))
            note = pretty_midi.Note(
                velocity=45, pitch=note_number, start=time, end=quarter_note_delta*3)
            piano.notes.append(note)
        time = time + quarter_note_delta*3


# Add the cello instrument to the PrettyMIDI object
piano_chord.instruments.append(piano)
# Write out the MIDI data
piano_chord.write('type2_chord.mid')
# Out:
# 0.34375

# %%
import pretty_midi
# Create a PrettyMIDI object
piano_chord = pretty_midi.PrettyMIDI()
# Create an Instrument instance for a cello instrument
piano_program = pretty_midi.instrument_name_to_program('Acoustic Grand Piano')
piano = pretty_midi.Instrument(program=piano_program)

part_number = 2
beat_time = 0.5
peroid_time = 16
total_time = 12
n = (total_time-2*0.5)/(peroid_time*part_number)
print(n)

# type 3
whole_note_delta = 2
half_note_delta = whole_note_delta/2
quarter_note_delta = whole_note_delta/4
time = 0
for i in range(part_number):
    time = (i)*len(base_notes)*whole_note_delta*2
    for chord in chords:
        for j in range(2):
            for base_note in chord:
                note_number = pretty_midi.note_name_to_number(
                    get_note_name(base_note-12))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=whole_note_delta)
                piano.notes.append(note)
            time = time + whole_note_delta

            note_number = pretty_midi.note_name_to_number(get_note_name(21))
            note = pretty_midi.Note(
                velocity=0, pitch=note_number, start=time, end=whole_note_delta)
            piano.notes.append(note)

    time = (i)*len(base_notes)*whole_note_delta*2
    for chord in chords:
        for j in range(2):
            for note in chord[::2]:
                note_number = pretty_midi.note_name_to_number(
                    get_note_name(note))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=quarter_note_delta)
                piano.notes.append(note)
            time = time + quarter_note_delta
            for note in chord[1::2]:
                note_number = pretty_midi.note_name_to_number(
                    get_note_name(note))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=quarter_note_delta)
                piano.notes.append(note)
            time = time + quarter_note_delta
            
        for note in chord[::2]:
            note_number = pretty_midi.note_name_to_number(
                get_note_name(note))
            note = pretty_midi.Note(
                velocity=45, pitch=note_number, start=time, end=quarter_note_delta)
            piano.notes.append(note)
        time = time + quarter_note_delta
        for note in chord[1::2]:
            note_number = pretty_midi.note_name_to_number(
                get_note_name(note))
            note = pretty_midi.Note(
                velocity=45, pitch=note_number, start=time, end=quarter_note_delta*3)
            piano.notes.append(note)
        time = time + quarter_note_delta*3


# Add the cello instrument to the PrettyMIDI object
piano_chord.instruments.append(piano)
# Write out the MIDI data
piano_chord.write('type3_chord.mid')
# Out:
# 0.34375

# %%
import pretty_midi
# Create a PrettyMIDI object
piano_chord = pretty_midi.PrettyMIDI()
# Create an Instrument instance for a cello instrument
piano_program = pretty_midi.instrument_name_to_program('Acoustic Grand Piano')
piano = pretty_midi.Instrument(program=piano_program)

part_number = 2
beat_time = 0.5
peroid_time = 16
total_time = 12
n = (total_time-2*0.5)/(peroid_time*part_number)
print(n)

# type 4
whole_note_delta = 2
half_note_delta = whole_note_delta/2
quarter_note_delta = whole_note_delta/4
time = 0
for i in range(part_number):
    time = (i)*len(base_notes)*whole_note_delta*3
    for chord in chords:
        for j in range(3):
            for base_note in chord:
                note_number = pretty_midi.note_name_to_number(
                    get_note_name(base_note-12))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=whole_note_delta)
                piano.notes.append(note)
            time = time + whole_note_delta

            note_number = pretty_midi.note_name_to_number(get_note_name(21))
            note = pretty_midi.Note(
                velocity=0, pitch=note_number, start=time, end=whole_note_delta)
            piano.notes.append(note)

    time = (i)*len(base_notes)*whole_note_delta*3
    for chord in chords:
        for j in range(4):
            for chord_note in chord:
                note_number = pretty_midi.note_name_to_number(
                    get_note_name(chord_note))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=quarter_note_delta)
                piano.notes.append(note)
            time = time + quarter_note_delta

            for chord_note in chord[2:]:
                note_number = pretty_midi.note_name_to_number(
                    get_note_name(chord_note-12))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=quarter_note_delta)
                piano.notes.append(note)
            time = time + quarter_note_delta
        for chord_note in chord:
            note_number = pretty_midi.note_name_to_number(
                get_note_name(chord_note))
            note = pretty_midi.Note(
                velocity=45, pitch=note_number, start=time, end=quarter_note_delta)
            piano.notes.append(note)
        time = time + quarter_note_delta
        for chord_note in chord+[chord[2]-12]:
            note_number = pretty_midi.note_name_to_number(
                get_note_name(chord_note))
            note = pretty_midi.Note(
                velocity=45, pitch=note_number, start=time, end=quarter_note_delta*3)
            piano.notes.append(note)
        time = time + quarter_note_delta*3
        


# Add the cello instrument to the PrettyMIDI object
piano_chord.instruments.append(piano)
# Write out the MIDI data
piano_chord.write('type4_chord.mid')
# Out:
# 0.34375

# %%
import pretty_midi
# Create a PrettyMIDI object
piano_chord = pretty_midi.PrettyMIDI()
# Create an Instrument instance for a cello instrument
piano_program = pretty_midi.instrument_name_to_program('Acoustic Grand Piano')
piano = pretty_midi.Instrument(program=piano_program)

part_number = 2
beat_time = 0.5
peroid_time = 16
total_time = 12
n = (total_time-2*0.5)/(peroid_time*part_number)
print(n)

# type 5
whole_note_delta = 2
half_note_delta = whole_note_delta/2
quarter_note_delta = whole_note_delta/4
time = 0
for i in range(part_number):
    time = (i)*len(base_notes)*whole_note_delta*3
    for chord in chords:
        for j in range(3):
            for base_note in chord:
                note_number = pretty_midi.note_name_to_number(
                    get_note_name(base_note-12))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=whole_note_delta)
                piano.notes.append(note)
            time = time + whole_note_delta

            note_number = pretty_midi.note_name_to_number(get_note_name(21))
            note = pretty_midi.Note(
                velocity=0, pitch=note_number, start=time, end=whole_note_delta)
            piano.notes.append(note)

    time = (i)*len(base_notes)*whole_note_delta*3
    for chord in chords:
        for j in range(2):
            for note in chord:
                note_number = pretty_midi.note_name_to_number(
                    get_note_name(note))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=quarter_note_delta)
                piano.notes.append(note)
                time = time + quarter_note_delta
            for note in chord[1::2]:
                note_number = pretty_midi.note_name_to_number(
                    get_note_name(note))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=quarter_note_delta)
                piano.notes.append(note)
                time = time + quarter_note_delta

        note_number = pretty_midi.note_name_to_number(
            get_note_name(chord[0]))
        note = pretty_midi.Note(
            velocity=45, pitch=note_number, start=time, end=whole_note_delta)
        piano.notes.append(note)
        time = time + whole_note_delta


# Add the cello instrument to the PrettyMIDI object
piano_chord.instruments.append(piano)
# Write out the MIDI data
piano_chord.write('type5-1_chord.mid')
# Out:
# 0.34375

# %%
import pretty_midi
# Create a PrettyMIDI object
piano_chord = pretty_midi.PrettyMIDI()
# Create an Instrument instance for a cello instrument
piano_program = pretty_midi.instrument_name_to_program('Acoustic Grand Piano')
piano = pretty_midi.Instrument(program=piano_program)

part_number = 1
beat_time = 0.5
peroid_time = 16
total_time = 12
n = (total_time-2*0.5)/(peroid_time*part_number)
print(n)

# type 6
whole_note_delta = 2
half_note_delta = whole_note_delta/2
quarter_note_delta = whole_note_delta/4
time = 0
for i in range(part_number):
    time = (i)*len(base_notes)*whole_note_delta*3
    for chord in chords:
        for j in range(2):
            time_delta = whole_note_delta
            if j==1:
                time_delta = whole_note_delta*2
            for base_note in chord:
                note_number = pretty_midi.note_name_to_number(
                    get_note_name(base_note-12))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=time_delta)
                piano.notes.append(note)
            time = time + time_delta

            note_number = pretty_midi.note_name_to_number(get_note_name(21))
            note = pretty_midi.Note(
                velocity=0, pitch=note_number, start=time, end=time_delta)
            piano.notes.append(note)
    note_order = [0,2,1,2]
    time = (i)*len(base_notes)*whole_note_delta*3
    for chord in chords:
        for j in range(2):
            time_delta = quarter_note_delta
            for k in range(len(note_order)):
                if j==1 and k==(len(note_order)-1):
                    time_delta = quarter_note_delta*5
                note_number = pretty_midi.note_name_to_number(
                    get_note_name(chord[note_order[k]]))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=time_delta)
                piano.notes.append(note)
                time = time + time_delta
        


# Add the cello instrument to the PrettyMIDI object
piano_chord.instruments.append(piano)
# Write out the MIDI data
piano_chord.write('type6_chord.mid')
# Out:
# 0.6875

# %%
import pretty_midi
# Create a PrettyMIDI object
piano_chord = pretty_midi.PrettyMIDI()
# Create an Instrument instance for a cello instrument
piano_program = pretty_midi.instrument_name_to_program('Acoustic Grand Piano')
piano = pretty_midi.Instrument(program=piano_program)

part_number = 1
beat_time = 0.5
peroid_time = 16
total_time = 12
n = (total_time-2*0.5)/(peroid_time*part_number)
print(n)

# type 7
whole_note_delta = 2
half_note_delta = whole_note_delta/2
quarter_note_delta = whole_note_delta/4
time = 0
for i in range(part_number):
    time = (i)*len(base_notes)*whole_note_delta*3
    for chord in chords:
        for j in range(2):
            time_delta = whole_note_delta
            if j==1:
                time_delta = whole_note_delta*2
            for base_note in chord:
                note_number = pretty_midi.note_name_to_number(
                    get_note_name(base_note-12))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=time_delta)
                piano.notes.append(note)
            time = time + time_delta

            note_number = pretty_midi.note_name_to_number(get_note_name(21))
            note = pretty_midi.Note(
                velocity=0, pitch=note_number, start=time, end=time_delta)
            piano.notes.append(note)
    note_order = [2, 0, 1, 0]
    time = (i)*len(base_notes)*whole_note_delta*3
    for chord in chords:
        for j in range(2):
            time_delta = quarter_note_delta
            for k in range(len(note_order)):
                if j==1 and k==(len(note_order)-1):
                    time_delta = quarter_note_delta*5
                note_number = pretty_midi.note_name_to_number(
                    get_note_name(chord[note_order[k]]))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=time_delta)
                piano.notes.append(note)
                time = time + time_delta
        


# Add the cello instrument to the PrettyMIDI object
piano_chord.instruments.append(piano)
# Write out the MIDI data
piano_chord.write('midi_file/type7_chord.mid')
# Out:
# 0.6875

# %%
import pretty_midi
# Create a PrettyMIDI object
piano_chord = pretty_midi.PrettyMIDI()
# Create an Instrument instance for a cello instrument
piano_program = pretty_midi.instrument_name_to_program('Acoustic Grand Piano')
piano = pretty_midi.Instrument(program=piano_program)

part_number = 2
beat_time = 0.5
peroid_time = 16
total_time = 12
n = (total_time-2*0.5)/(peroid_time*part_number)
print(n)

# type 8
whole_note_delta = 2
half_note_delta = whole_note_delta/2
quarter_note_delta = whole_note_delta/4
time = 0
for i in range(part_number):
    time = (i)*len(base_notes)*whole_note_delta*3
    for chord in chords:
        for j in range(3):
            for base_note in chord:
                note_number = pretty_midi.note_name_to_number(
                    get_note_name(base_note-12))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=whole_note_delta)
                piano.notes.append(note)
            time = time + whole_note_delta

            note_number = pretty_midi.note_name_to_number(get_note_name(21))
            note = pretty_midi.Note(
                velocity=0, pitch=note_number, start=time, end=whole_note_delta)
            piano.notes.append(note)

    time = (i)*len(base_notes)*whole_note_delta*3
    for chord in chords:
        for j in range(2):
            for chord_note in chord:
                note_number = pretty_midi.note_name_to_number(
                    get_note_name(chord_note))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=quarter_note_delta)
                piano.notes.append(note)
                
                if chord_note == chord[2]:
                    note_number = pretty_midi.note_name_to_number(
                        get_note_name(chord[0]))
                    note = pretty_midi.Note(
                        velocity=45, pitch=note_number, start=time, end=quarter_note_delta)
                    piano.notes.append(note)
                time = time + quarter_note_delta
                    
            for chord_note in chord[1::2]:
                note_number = pretty_midi.note_name_to_number(
                    get_note_name(chord_note))
                note = pretty_midi.Note(
                    velocity=45, pitch=note_number, start=time, end=quarter_note_delta)
                piano.notes.append(note)
                time = time + quarter_note_delta

        note_number = pretty_midi.note_name_to_number(
            get_note_name(chord[0]))
        note = pretty_midi.Note(
            velocity=45, pitch=note_number, start=time, end=whole_note_delta)
        piano.notes.append(note)
        time = time + whole_note_delta


# Add the cello instrument to the PrettyMIDI object
piano_chord.instruments.append(piano)
# Write out the MIDI data
piano_chord.write('type5-2_chord.mid')
# Out:
# 0.34375

# %%
def change_pitch_scale(scale_name, pitch):
    delta = 0
    if scale_name == "C":
        delta = 0
    elif scale_name == "bC":
        delta = -1
    elif scale_name == "bD":
        delta = 1
    elif scale_name == "D":
        delta = 2
    elif scale_name == "bE":
        delta = 3
    elif scale_name == "E":
        delta = 4
    elif scale_name == "F":
        delta = 5
    elif scale_name == "bG":
        delta = 6
    elif scale_name == "G":
        delta = 7
    elif scale_name == "bA":
        delta = 8
    elif scale_name == "A":
        delta = 9
    elif scale_name == "bB":
        delta = 10
    elif scale_name == "B":
        delta = 11
    pitch = pitch + delta
    return pitch

# %%
def change_scale(pretty_midi, scale_name):
    for track in pretty_midi.instruments:
        for note in track.notes:
            note.pitch = change_pitch_scale(scale_name, note.pitch)
    return pretty_midi

# %%
piano_chord.instruments[0].notes
# Out:
# [Note(start=0.000000, end=2.000000, pitch=48, velocity=45),
#  Note(start=0.000000, end=2.000000, pitch=52, velocity=45),
#  Note(start=0.000000, end=2.000000, pitch=55, velocity=45),
#  Note(start=2.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=2.000000, end=2.000000, pitch=48, velocity=45),
#  Note(start=2.000000, end=2.000000, pitch=52, velocity=45),
#  Note(start=2.000000, end=2.000000, pitch=55, velocity=45),
#  Note(start=4.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=4.000000, end=2.000000, pitch=48, velocity=45),
#  Note(start=4.000000, end=2.000000, pitch=52, velocity=45),
#  Note(start=4.000000, end=2.000000, pitch=55, velocity=45),
#  Note(start=6.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=6.000000, end=2.000000, pitch=57, velocity=45),
#  Note(start=6.000000, end=2.000000, pitch=60, velocity=45),
#  Note(start=6.000000, end=2.000000, pitch=64, velocity=45),
#  Note(start=8.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=8.000000, end=2.000000, pitch=57, velocity=45),
#  Note(start=8.000000, end=2.000000, pitch=60, velocity=45),
#  Note(start=8.000000, end=2.000000, pitch=64, velocity=45),
#  Note(start=10.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=10.000000, end=2.000000, pitch=57, velocity=45),
#  Note(start=10.000000, end=2.000000, pitch=60, velocity=45),
#  Note(start=10.000000, end=2.000000, pitch=64, velocity=45),
#  Note(start=12.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=12.000000, end=2.000000, pitch=53, velocity=45),
#  Note(start=12.000000, end=2.000000, pitch=57, velocity=45),
#  Note(start=12.000000, end=2.000000, pitch=60, velocity=45),
#  Note(start=14.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=14.000000, end=2.000000, pitch=53, velocity=45),
#  Note(start=14.000000, end=2.000000, pitch=57, velocity=45),
#  Note(start=14.000000, end=2.000000, pitch=60, velocity=45),
#  Note(start=16.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=16.000000, end=2.000000, pitch=53, velocity=45),
#  Note(start=16.000000, end=2.000000, pitch=57, velocity=45),
#  Note(start=16.000000, end=2.000000, pitch=60, velocity=45),
#  Note(start=18.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=18.000000, end=2.000000, pitch=55, velocity=45),
#  Note(start=18.000000, end=2.000000, pitch=59, velocity=45),
#  Note(start=18.000000, end=2.000000, pitch=62, velocity=45),
#  Note(start=20.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=20.000000, end=2.000000, pitch=55, velocity=45),
#  Note(start=20.000000, end=2.000000, pitch=59, velocity=45),
#  Note(start=20.000000, end=2.000000, pitch=62, velocity=45),
#  Note(start=22.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=22.000000, end=2.000000, pitch=55, velocity=45),
#  Note(start=22.000000, end=2.000000, pitch=59, velocity=45),
#  Note(start=22.000000, end=2.000000, pitch=62, velocity=45),
#  Note(start=24.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=0.000000, end=0.500000, pitch=60, velocity=45),
#  Note(start=0.500000, end=0.500000, pitch=64, velocity=45),
#  Note(start=1.000000, end=0.500000, pitch=67, velocity=45),
#  Note(start=1.000000, end=0.500000, pitch=60, velocity=45),
#  Note(start=1.500000, end=0.500000, pitch=64, velocity=45),
#  Note(start=2.000000, end=0.500000, pitch=60, velocity=45),
#  Note(start=2.500000, end=0.500000, pitch=64, velocity=45),
#  Note(start=3.000000, end=0.500000, pitch=67, velocity=45),
#  Note(start=3.000000, end=0.500000, pitch=60, velocity=45),
#  Note(start=3.500000, end=0.500000, pitch=64, velocity=45),
#  Note(start=4.000000, end=2.000000, pitch=60, velocity=45),
#  Note(start=6.000000, end=0.500000, pitch=69, velocity=45),
#  Note(start=6.500000, end=0.500000, pitch=72, velocity=45),
#  Note(start=7.000000, end=0.500000, pitch=76, velocity=45),
#  Note(start=7.000000, end=0.500000, pitch=69, velocity=45),
#  Note(start=7.500000, end=0.500000, pitch=72, velocity=45),
#  Note(start=8.000000, end=0.500000, pitch=69, velocity=45),
#  Note(start=8.500000, end=0.500000, pitch=72, velocity=45),
#  Note(start=9.000000, end=0.500000, pitch=76, velocity=45),
#  Note(start=9.000000, end=0.500000, pitch=69, velocity=45),
#  Note(start=9.500000, end=0.500000, pitch=72, velocity=45),
#  Note(start=10.000000, end=2.000000, pitch=69, velocity=45),
#  Note(start=12.000000, end=0.500000, pitch=65, velocity=45),
#  Note(start=12.500000, end=0.500000, pitch=69, velocity=45),
#  Note(start=13.000000, end=0.500000, pitch=72, velocity=45),
#  Note(start=13.000000, end=0.500000, pitch=65, velocity=45),
#  Note(start=13.500000, end=0.500000, pitch=69, velocity=45),
#  Note(start=14.000000, end=0.500000, pitch=65, velocity=45),
#  Note(start=14.500000, end=0.500000, pitch=69, velocity=45),
#  Note(start=15.000000, end=0.500000, pitch=72, velocity=45),
#  Note(start=15.000000, end=0.500000, pitch=65, velocity=45),
#  Note(start=15.500000, end=0.500000, pitch=69, velocity=45),
#  Note(start=16.000000, end=2.000000, pitch=65, velocity=45),
#  Note(start=18.000000, end=0.500000, pitch=67, velocity=45),
#  Note(start=18.500000, end=0.500000, pitch=71, velocity=45),
#  Note(start=19.000000, end=0.500000, pitch=74, velocity=45),
#  Note(start=19.000000, end=0.500000, pitch=67, velocity=45),
#  Note(start=19.500000, end=0.500000, pitch=71, velocity=45),
#  Note(start=20.000000, end=0.500000, pitch=67, velocity=45),
#  Note(start=20.500000, end=0.500000, pitch=71, velocity=45),
#  Note(start=21.000000, end=0.500000, pitch=74, velocity=45),
#  Note(start=21.000000, end=0.500000, pitch=67, velocity=45),
#  Note(start=21.500000, end=0.500000, pitch=71, velocity=45),
#  Note(start=22.000000, end=2.000000, pitch=67, velocity=45),
#  Note(start=24.000000, end=2.000000, pitch=48, velocity=45),
#  Note(start=24.000000, end=2.000000, pitch=52, velocity=45),
#  Note(start=24.000000, end=2.000000, pitch=55, velocity=45),
#  Note(start=26.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=26.000000, end=2.000000, pitch=48, velocity=45),
#  Note(start=26.000000, end=2.000000, pitch=52, velocity=45),
#  Note(start=26.000000, end=2.000000, pitch=55, velocity=45),
#  Note(start=28.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=28.000000, end=2.000000, pitch=48, velocity=45),
#  Note(start=28.000000, end=2.000000, pitch=52, velocity=45),
#  Note(start=28.000000, end=2.000000, pitch=55, velocity=45),
#  Note(start=30.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=30.000000, end=2.000000, pitch=57, velocity=45),
#  Note(start=30.000000, end=2.000000, pitch=60, velocity=45),
#  Note(start=30.000000, end=2.000000, pitch=64, velocity=45),
#  Note(start=32.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=32.000000, end=2.000000, pitch=57, velocity=45),
#  Note(start=32.000000, end=2.000000, pitch=60, velocity=45),
#  Note(start=32.000000, end=2.000000, pitch=64, velocity=45),
#  Note(start=34.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=34.000000, end=2.000000, pitch=57, velocity=45),
#  Note(start=34.000000, end=2.000000, pitch=60, velocity=45),
#  Note(start=34.000000, end=2.000000, pitch=64, velocity=45),
#  Note(start=36.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=36.000000, end=2.000000, pitch=53, velocity=45),
#  Note(start=36.000000, end=2.000000, pitch=57, velocity=45),
#  Note(start=36.000000, end=2.000000, pitch=60, velocity=45),
#  Note(start=38.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=38.000000, end=2.000000, pitch=53, velocity=45),
#  Note(start=38.000000, end=2.000000, pitch=57, velocity=45),
#  Note(start=38.000000, end=2.000000, pitch=60, velocity=45),
#  Note(start=40.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=40.000000, end=2.000000, pitch=53, velocity=45),
#  Note(start=40.000000, end=2.000000, pitch=57, velocity=45),
#  Note(start=40.000000, end=2.000000, pitch=60, velocity=45),
#  Note(start=42.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=42.000000, end=2.000000, pitch=55, velocity=45),
#  Note(start=42.000000, end=2.000000, pitch=59, velocity=45),
#  Note(start=42.000000, end=2.000000, pitch=62, velocity=45),
#  Note(start=44.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=44.000000, end=2.000000, pitch=55, velocity=45),
#  Note(start=44.000000, end=2.000000, pitch=59, velocity=45),
#  Note(start=44.000000, end=2.000000, pitch=62, velocity=45),
#  Note(start=46.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=46.000000, end=2.000000, pitch=55, velocity=45),
#  Note(start=46.000000, end=2.000000, pitch=59, velocity=45),
#  Note(start=46.000000, end=2.000000, pitch=62, velocity=45),
#  Note(start=48.000000, end=2.000000, pitch=21, velocity=0),
#  Note(start=24.000000, end=0.500000, pitch=60, velocity=45),
#  Note(start=24.500000, end=0.500000, pitch=64, velocity=45),
#  Note(start=25.000000, end=0.500000, pitch=67, velocity=45),
#  Note(start=25.000000, end=0.500000, pitch=60, velocity=45),
#  Note(start=25.500000, end=0.500000, pitch=64, velocity=45),
#  Note(start=26.000000, end=0.500000, pitch=60, velocity=45),
#  Note(start=26.500000, end=0.500000, pitch=64, velocity=45),
#  Note(start=27.000000, end=0.500000, pitch=67, velocity=45),
#  Note(start=27.000000, end=0.500000, pitch=60, velocity=45),
#  Note(start=27.500000, end=0.500000, pitch=64, velocity=45),
#  Note(start=28.000000, end=2.000000, pitch=60, velocity=45),
#  Note(start=30.000000, end=0.500000, pitch=69, velocity=45),
#  Note(start=30.500000, end=0.500000, pitch=72, velocity=45),
#  Note(start=31.000000, end=0.500000, pitch=76, velocity=45),
#  Note(start=31.000000, end=0.500000, pitch=69, velocity=45),
#  Note(start=31.500000, end=0.500000, pitch=72, velocity=45),
#  Note(start=32.000000, end=0.500000, pitch=69, velocity=45),
#  Note(start=32.500000, end=0.500000, pitch=72, velocity=45),
#  Note(start=33.000000, end=0.500000, pitch=76, velocity=45),
#  Note(start=33.000000, end=0.500000, pitch=69, velocity=45),
#  Note(start=33.500000, end=0.500000, pitch=72, velocity=45),
#  Note(start=34.000000, end=2.000000, pitch=69, velocity=45),
#  Note(start=36.000000, end=0.500000, pitch=65, velocity=45),
#  Note(start=36.500000, end=0.500000, pitch=69, velocity=45),
#  Note(start=37.000000, end=0.500000, pitch=72, velocity=45),
#  Note(start=37.000000, end=0.500000, pitch=65, velocity=45),
#  Note(start=37.500000, end=0.500000, pitch=69, velocity=45),
#  Note(start=38.000000, end=0.500000, pitch=65, velocity=45),
#  Note(start=38.500000, end=0.500000, pitch=69, velocity=45),
#  Note(start=39.000000, end=0.500000, pitch=72, velocity=45),
#  Note(start=39.000000, end=0.500000, pitch=65, velocity=45),
#  Note(start=39.500000, end=0.500000, pitch=69, velocity=45),
#  Note(start=40.000000, end=2.000000, pitch=65, velocity=45),
#  Note(start=42.000000, end=0.500000, pitch=67, velocity=45),
#  Note(start=42.500000, end=0.500000, pitch=71, velocity=45),
#  Note(start=43.000000, end=0.500000, pitch=74, velocity=45),
#  Note(start=43.000000, end=0.500000, pitch=67, velocity=45),
#  Note(start=43.500000, end=0.500000, pitch=71, velocity=45),
#  Note(start=44.000000, end=0.500000, pitch=67, velocity=45),
#  Note(start=44.500000, end=0.500000, pitch=71, velocity=45),
#  Note(start=45.000000, end=0.500000, pitch=74, velocity=45),
#  Note(start=45.000000, end=0.500000, pitch=67, velocity=45),
#  Note(start=45.500000, end=0.500000, pitch=71, velocity=45),
#  Note(start=46.000000, end=2.000000, pitch=67, velocity=45)]

# %%
new_piano_chord = change_scale(piano_chord, "G")

# %%
new_piano_chord.instruments[0].notes[0].pitch
# Out:
# 55

# %%
piano_chord.write('midi_file/base_chord_G.mid')

# %%
midi_data = pretty_midi.PrettyMIDI('midi_file/Happy_01.mid')

# %%
minor_list = [["E", "A", "B"], ["B"], ["B", "E"]]
def change_to_minor(midi):
    for track in midi.instruments:
        for note in track.notes:
            pitch = pretty_midi.note_number_to_name(note.pitch)
            if pitch[0] in minor_list[0] and pitch[1]!='#':
                note.pitch = note.pitch - 1
    return midi

# %%
change_to_minor(piano_chord)

# %%
pretty_midi.note_number_to_name(60)[0]
# Out:
# 'C'
