# %%
from midi2audio import FluidSynth
soundfont = "C:\\Users\\ASUS\\Downloads\\YDP-GrandPiano-SF2-20160804\\YDP-GrandPiano-20160804.sf2"
fs = FluidSynth(sound_font=soundfont, sample_rate=22050)
fs.midi_to_audio('input.mid', 'output.mid')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [1], line 4
#       2 soundfont = "C:\\Users\\ASUS\\Downloads\\YDP-GrandPiano-SF2-20160804\\YDP-GrandPiano-20160804.sf2"
#       3 fs = FluidSynth(sound_font=soundfont, sample_rate=22050)
# ----> 4 fs.midi_to_audio('input.mid', 'output.mid')
#
# File ~\miniconda3\lib\site-packages\midi2audio.py:46, in FluidSynth.midi_to_audio(self, midi_file, audio_file)
#      45 def midi_to_audio(self, midi_file, audio_file):
# ---> 46     subprocess.call(['fluidsynth', '-ni', self.sound_font, midi_file, '-F', audio_file, '-r', str(self.sample_rate)])
#
# File ~\miniconda3\lib\subprocess.py:349, in call(timeout, *popenargs, **kwargs)
#     341 def call(*popenargs, timeout=None, **kwargs):
#     342     """Run command with arguments.  Wait for command to complete or
#     343     timeout, then return the returncode attribute.
#     344
# ...

# %%
import pretty_midi
import numpy as np
import fluidsynth
# For plotting
#import mir_eval.display
#import librosa.display
import matplotlib.pyplot as plt
# %matplotlib inline
# For putting audio in the notebook
import IPython.display
# Out:
# libfluidsynth64.dll

# %%
import pretty_midi
# Load MIDI file into PrettyMIDI object
midi_data = pretty_midi.PrettyMIDI('input.mid')

# %%
fs = 32000
IPython.display.Audio(midi_data.synthesize(fs=fs), rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
IPython.display.Audio(midi_data.fluidsynth(fs=16000), rate=16000)
# Out:
# C:\Users\ASUS\miniconda3\lib\site-packages\pretty_midi\instrument.py:167: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if bend_int is not 0:
# C:\Users\ASUS\miniconda3\lib\site-packages\pretty_midi\instrument.py:176: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if bend_int is not 0:
# C:\Users\ASUS\miniconda3\lib\site-packages\pretty_midi\instrument.py:167: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if bend_int is not 0:
# C:\Users\ASUS\miniconda3\lib\site-packages\pretty_midi\instrument.py:176: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if bend_int is not 0:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 IPython.display.Audio(midi_data.fluidsynth(fs=16000), rate=16000)
#
# ...

# %%
try:
    import fluidsynth
    _HAS_FLUIDSYNTH = True
except ImportError:
    _HAS_FLUIDSYNTH = False
# Out:
# Traceback (most recent call last):
#
#   File ~\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3378 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In [15], line 2
#     import fluidsynth
#
#   File ~\miniconda3\lib\site-packages\fluidsynth.py:36
#     raise ImportError, "Couldn't find the FluidSynth library."
#                      ^
# SyntaxError: invalid syntax

# %%
_HAS_FLUIDSYNTH
# Out:
# True

# %%
from ctypes import *
from ctypes.util import find_library
lib = find_library('fluidsynth') or find_library('libfluidsynth64') or find_library('libfluidsynth-3')

# %%
lib
# Out:
# 'libfluidsynth64.dll'
